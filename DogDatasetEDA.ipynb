# %%
from src.data_loader import load_dog_data
from sklearn.decomposition import PCA
from src.utils import PCA_images_list, unravel_image, ravel_image_vec, plot_image_grid
import numpy as np
import pickle
data_path = r'C:\Users\Alexander Dong\IncubatorCVProject\DogsDataset\images\Images'

# %%
(image_list,label_list,label_dict) = load_dog_data(data_path,
              image_shape=(64,64),
              sample_rate=1, 
              simple=False)

# %%
(eig_vals,eig_image_list) = PCA_images_list(image_list,n_components=None)

# %%
plot_image_grid(eig_vec_list[0:10],title='asd',ncols=5,nrows=2)

# %%
len(eig_vals)
# Out:
# 4096

# %%
sum(eig_vals[0:250])/sum(eig_vals)
# Out:
# 0.8909262786922952

# %%
pickle.dump( (eig_vals,eig_vec_list), open( "eigvalsvecs.p", "wb" ) )
